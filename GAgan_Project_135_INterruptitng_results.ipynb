# %% [markdown]
# <a href="https://colab.research.google.com/github/Gagancoder/-F-R-D-DDY-/blob/main/GAgan_Project_135_INterruptitng_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5306e792-b906-4aa1-ac0d-1fcaf4bf25c7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5306e792-b906-4aa1-ac0d-1fcaf4bf25c7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Filter_stars.csv to Filter_stars.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import csv

# %%
rows = []

with open("Filter_stars.csv","r") as f:
  csvreader = csv.reader(f)
  for row in csvreader :
    rows.append(row)

stars_data_rows = rows[1:]

print(stars_data_rows[0])
stars_data = stars_data_rows[1:]
# Out:
# ['0', '0', 'Sun', '0.000015813', '1.0', '1.0', '274.2691614595739']

# %%
df = pd.read_csv("Filter_stars.csv")


mass = df["Mass"].to_list()
star_name = df["Star_name"].to_list()
distance = df["Distance"].to_list()
gravity = df["Gravity"].to_list()
radius = df["Radius"].to_list()

# %%
fig = px.bar(x = star_name , y = mass )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig2 = px.bar(x = star_name , y = radius)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = px.bar(x = star_name , y = distance)
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig4 = px.bar(x = star_name , y = gravity)
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# I found This different types of Graps

# %% [markdown]
# ### P-136

# %%
final_planet_list = []

for planet_data in stars_data_rows:
  temp_dict = {
                  "Star_name": stars_data[1],
                  "Distance": stars_data[2],
                  "Mass": stars_data[3],
                  "Radius": stars_data[4],
                  "Gravity": stars_data[5],
              }
  final_planet_list.append(temp_dict)

print(final_planet_list)
# Out:
# [{'Star_name': ['2', '2', 'Canopus', '310', '15.0', '71.0', '0.8161153386021839'], 'Distance': ['3', '3', 'Alpha Centauri', '4.4', '1.1', '1.2', '209.51116500384123'], 'Mass': ['4', '4', 'Arcturus', '37', '1.1', '26.0', '0.4462959727892475'], 'Radius': ['5', '5', 'Vega', '25', '2.2', '2.7', '82.76984296448046'], 'Gravity': ['6', '6', 'Capella', '43', '2.6', '12.0', '4.952082081908975']}, {'Star_name': ['2', '2', 'Canopus', '310', '15.0', '71.0', '0.8161153386021839'], 'Distance': ['3', '3', 'Alpha Centauri', '4.4', '1.1', '1.2', '209.51116500384123'], 'Mass': ['4', '4', 'Arcturus', '37', '1.1', '26.0', '0.4462959727892475'], 'Radius': ['5', '5', 'Vega', '25', '2.2', '2.7', '82.76984296448046'], 'Gravity': ['6', '6', 'Capella', '43', '2.6', '12.0', '4.952082081908975']}, {'Star_name': ['2', '2', 'Canopus', '310', '15.0', '71.0', '0.8161153386021839'], 'Distance': ['3', '3', 'Alpha Centauri', '4.4', '1.1', '1.2', '209.51116500384123'], 'Mass': ['4', '4', 'Arcturus', '37', '1.1', '26.0'
# ...
